# %% [markdown]
# # Testing network path

# %%
import pandas as pd

# %%
sheetname = 'base_billings' 
fn = r'/Volumes/Treasury/Financial_Database/Deferred_Revenue/Inputs/Data_2020_p12/all_billings_inputs.xlsx'

# %%
df = pd.read_excel(fn, sheet_name = sheetname)

# %%
df.head(10)
# Out:
#    Contrct Duration in Months Document Currency Enterprise BU Desc  \
# 0                         NaN               USD           Creative
# 1                         NaN               USD     Document Cloud
# 2                         0.0               AUD           Creative
# 3                         0.0               AUD           Creative
# 4                         0.0               AUD           Creative
# 5                         0.0               AUD           Creative
# 6                         0.0               AUD           Creative
# 7                         0.0               AUD           Creative
# 8                         0.0               AUD           Creative
# 9                         0.0               AUD           Creative
#
#   Invoice Fiscal Year Period Desc POB Type Product Config Type  \
# 0                         2020-09       RR                  1Y
# 1                         2020-09       RR                  1Y
# ...

# %% [markdown]
# # Working on the bookings files
#
# The
