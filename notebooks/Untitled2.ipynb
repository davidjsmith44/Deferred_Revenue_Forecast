# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('../data/Data_2021_p03/all_billings_weekly.xlsx', sheet_name='base_billings')

# %%
df.head()
# Out:
#   Document Currency Enterprise BU Desc Invoice Calendar Year Week Desc  \
# 0               AUD           Creative                         2018-01
# 1               AUD   Experience Cloud                         2018-01
# 2               AUD   Experience Cloud                         2018-01
# 3               AUD   Experience Cloud                         2018-01
# 4               AUD   Experience Cloud                         2018-01
#
#   POB Type Product Config Type Rev Rec Category Rule For Bill Date  \
# 0      NaN                  1Y                D                 YA
# 1      NaN                 NaN                D                 YA
# 2      NaN               OCONS                B                NaN
# 3      NaN               ONORE                D                 YA
# 4      NaN               ONORE                D                 YQ
#
#   Sales Document Type Sales Type  Subscription Term  Completed Sales ( DC )
# ...

# %%
df.head(20)
# Out:
#    Document Currency Enterprise BU Desc Invoice Calendar Year Week Desc  \
# 0                AUD           Creative                         2018-01
# 1                AUD   Experience Cloud                         2018-01
# 2                AUD   Experience Cloud                         2018-01
# 3                AUD   Experience Cloud                         2018-01
# 4                AUD   Experience Cloud                         2018-01
# 5                CAD   Experience Cloud                         2018-01
# 6                CAD   Experience Cloud                         2018-01
# 7                EUR           Creative                         2018-01
# 8                EUR   Experience Cloud                         2018-01
# 9                EUR   Experience Cloud                         2018-01
# 10               EUR   Experience Cloud                         2018-01
# 11               EUR   Experience Cloud                         2018-01
# ...
