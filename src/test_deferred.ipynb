# %% [markdown]
# ## Testing Deferred Revenue in Python
# Will this be easier for everyone to use than Matlab?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel('inputs/base_billings.xlsx', sheet_name='bill_DC')

# %%
df.head()
# Out:
#   Document Currency Enterprise Bu Frequency Invoicing Fiscal Year-Period Desc  \
# 0               ARS      Creative       NaN                           2019-03
# 1               ARS      Creative       NaN                           2019-03
# 2               ARS      Creative       NaN                           2019-03
# 3               ARS      Creative       NaN                           2019-03
# 4               ARS      Creative       NaN                           2019-03
#
#   Product Configtype ID Revenue Recognition Category New Rule For Bill Date  \
# 0                    1Y                                D                NaN
# 1                    1Y                                D                 Y3
# 2                    1Y                                D                 YA
# 3                 MTHLY                                D                NaN
# 4                 MTHLY                                D                 Y3
#
#   Sales Type  Subscription Term  Completed Sales Doc Currency
# 0   DEFERRED                  1                     -11291.52
# 1   DEFERRED                  1                     373766.00
# 2   DEFERRED                 12                     241380.00
# 3   DEFERRED                  1                      -1221.00
# 4   DEFERRED                  1                      45799.00

# %%
df.tail()
# Out:
#       Document Currency       Enterprise Bu Frequency  \
# 31441               USD  Print & Publishing      ONGO
# 31442               USD  Print & Publishing      ONGO
# 31443               USD  Print & Publishing      ONGO
# 31444               USD  Print & Publishing      ONGO
# 31445               USD  Print & Publishing      ONGO
#
#       Invoicing Fiscal Year-Period Desc Product Configtype ID  \
# 31441                           2019-03                    1Y
# 31442                           2019-03                    1Y
# 31443                           2019-03                    1Y
# 31444                           2019-03                    1Y
# 31445                           2019-03                    1Y
#
#       Revenue Recognition Category New Rule For Bill Date Sales Type  \
# 31441                              NaN                NaN   DEFERRED
# 31442                                D                 Y1   DEFERRED
# 31443                                D                 YA   DEFERRED
# 31444                                D                 YA   DEFERRED
# 31445                                D                 YQ   DEFERRED
#
#        Subscription Term  Completed Sales Doc Currency
# 31441                 12                          0.00
# 31442                  0                       2187.50
# 31443                  0                      10000.00
# 31444                 12                     169475.37
# 31445                 12                       5000.00

# %%
df.sample(20)
# Out:
#       Document Currency       Enterprise Bu Frequency  \
# 4871                CHF            Creative       NaN
# 29175               USD    Experience Cloud      1TME
# 22957               SEK      Document Cloud       NaN
# 705                 AUD            Creative       NaN
# 25160               USD            Creative      ONGO
# 29898               USD    Experience Cloud      ONGO
# 28378               USD    Experience Cloud      ONGO
# 30177               USD           LiveCycle       NaN
# 3194                AUD  Print & Publishing       NaN
# 13694               GBP            Creative       NaN
# 26860               USD    Experience Cloud       NaN
# 15712               GBP    Experience Cloud      ONGO
# 18203               JPY            Creative       NaN
# 23479               SEK     Other Solutions       NaN
# 23487               SEK     Other Solutions       NaN
# 10688               EUR    Experience Cloud      ONGO
# 13214               EUR  Print & Publishing       NaN
# 25290               USD            Creative       NaN
# 15958               GBP    Experience Cloud      1TME
# 7540                DKK    Experience Cloud      ACTL
#
#       Invoicing Fiscal Year-Period Desc Product Configtype ID  \
# 4871                            2015-11                    1Y
# 29175                           2018-02                   NaN
# 22957                           2018-05                    1Y
# 705                             2018-09                   NaN
# 25160                           2018-06                    1Y
# 29898                           2018-12                 MTHLY
# 28378                           2017-02                 ONORE
# 30177                           2016-05                   NaN
# 3194                            2016-08                    2Y
# 13694                           2017-07                   NaN
# 26860                           2015-07                    1Y
# 15712                           2017-05                    1Y
# 18203                           2018-10                    1Y
# 23479                           2018-02                   NaN
# 23487                           2018-08                   NaN
# 10688                           2016-08                 ONORE
# 13214                           2019-02                    1Y
# 25290                           2018-10                    1Y
# 15958                           2018-01                 OUNIV
# 7540                            2017-04                 ONORE
#
#       Revenue Recognition Category New Rule For Bill Date   Sales Type  \
# 4871                                 A                NaN     DEFERRED
# 29175                              NaN                NaN      NON-REV
# 22957                                D                 Y3     DEFERRED
# 705                                NaN                NaN     DEFERRED
# 25160                                D                 YQ     DEFERRED
# 29898                                D                 YA     DEFERRED
# 28378                                D                 Y2     DEFERRED
# 30177                              NaN                NaN   RECOGNIZED
# 3194                                 A                NaN     DEFERRED
# 13694                                A                NaN     DEFERRED
# 26860                                D                 YQ     DEFERRED
# 15712                                D                 Y2     DEFERRED
# 18203                                A                NaN     DEFERRED
# 23479                              NaN                NaN   RECOGNIZED
# 23487                              NaN                NaN   RECOGNIZED
# 10688                                D                 YA     DEFERRED
# 13214                                D                 YA     DEFERRED
# 25290                              NaN                NaN     DEFERRED
# 15958                              NaN                NaN  PRO-SVC-INV
# 7540                               NaN                NaN   RECOGNIZED
#
#        Subscription Term  Completed Sales Doc Currency
# 4871                   1                     -10980.85
# 29175                  0                     181905.00
# 22957                  1                     173391.00
# 705                    0                       7831.97
# 25160                  0                      -8500.00
# 29898                  0                    1156110.72
# 28378                  0                      30535.00
# 30177                  0                     113752.52
# 3194                   0                       2745.00
# 13694                  1                        -34.72
# 26860                  0                      60209.81
# 15712                 12                       4650.00
# 18203                  1                   11357437.00
# 23479                  0                      -1028.75
# 23487                  0                       -780.09
# 10688                  0                      28595.01
# 13214                 12                     299521.90
# 25290                  0                          0.00
# 15958                  0                      11749.00
# 7540                   0                      35434.10

# %%
df['Document Currency'].value_counts()
# Out:
# USD    7791
# EUR    5291
# GBP    3917
# AUD    3500
# JPY    3202
# CHF    1678
# SEK    1492
# DKK    1455
# NOK    1307
# CAD    1109
# HKD     231
# RUB     199
# BRL     184
# NZD      38
# KRW      12
# SGD      12
# COP       7
# CLP       7
# ARS       6
# PEN       5
# INR       1
# MXP       1
# BMD       1
# Name: Document Currency, dtype: int64

# %% [markdown]
# ## Possibly have a filter here that removes any currency that has a value count < 10.
# So there are less than 10 transactions

# %%
vc = df['Document Currency'].value_counts()
vc
# Out:
# USD    7791
# EUR    5291
# GBP    3917
# AUD    3500
# JPY    3202
# CHF    1678
# SEK    1492
# DKK    1455
# NOK    1307
# CAD    1109
# HKD     231
# RUB     199
# BRL     184
# NZD      38
# KRW      12
# SGD      12
# COP       7
# CLP       7
# ARS       6
# PEN       5
# INR       1
# MXP       1
# BMD       1
# Name: Document Currency, dtype: int64

# %%
vc.index

# %%
vc.values

# %%
a.values

# %%
keep_these = vc.values > 10
keep_these
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True, False, False,
#        False, False, False, False, False])

# %%
keep_curr = vc[keep_these]
a = keep_curr.index

# %%
df = df[df['Document Currency'].isin(a)]

# %%
whos
# Out:
# Variable     Type         Data/Info
# -----------------------------------
# a            Index        Index(['USD', 'EUR', 'GBP<...>],\n      dtype='object')
# df           DataFrame          Document Currency  <...>[31418 rows x 10 columns]
# keep_curr    Series       USD    7791\nEUR    5291\<...>nt Currency, dtype: int64
# keep_these   ndarray      23: 23 elems, type `bool`, 23 bytes
# new_df       DataFrame    Empty DataFrame\nColumns:<...> Doc Currency]\nIndex: []
# np           module       <module 'numpy' from '/an<...>kages/numpy/__init__.py'>
# pd           module       <module 'pandas' from '/a<...>ages/pandas/__init__.py'>
# plt          module       <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# vc           Series       USD    7791\nEUR    5291\<...>nt Currency, dtype: int64

# %%
new_df['Completed Sales Doc Currency'].value_counts()

# %%
df = df[df['Completed Sales Doc Currency']!=0]

# %%
df.head()
# Out:
#    Document Currency Enterprise Bu Frequency  \
# 6                AUD      Creative       NaN
# 7                AUD      Creative       NaN
# 8                AUD      Creative       NaN
# 9                AUD      Creative       NaN
# 10               AUD      Creative       NaN
#
#    Invoicing Fiscal Year-Period Desc Product Configtype ID  \
# 6                            2015-06                   NaN
# 7                            2015-06                   NaN
# 8                            2015-06                   NaN
# 9                            2015-06                   NaN
# 10                           2015-06                   NaN
#
#    Revenue Recognition Category New Rule For Bill Date  Sales Type  \
# 6                               NaN                NaN  RECOGNIZED
# 7                                 A                NaN    DEFERRED
# 8                                 A                NaN    DEFERRED
# 9                                 A                NaN    DEFERRED
# 10                                D                 Y3    DEFERRED
#
#     Subscription Term  Completed Sales Doc Currency
# 6                   0                     474551.11
# 7                   0                     447996.81
# 8                   1                       4343.94
# 9                  12                        524.93
# 10                  1                       1622.68

# %%
test.sample(20)

# %%
for (method, group) in planets.groupby('method'):
    print("{0:30s} shape={1}".format(method, group.shape))
